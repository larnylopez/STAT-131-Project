# %% [markdown]
# # STATS 131 Project
# Predicting House Sales in King County, USA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
from scipy.stats import skew
from scipy import stats
from scipy.stats.stats import pearsonr
from scipy.stats import norm
from collections import Counter
from sklearn.linear_model import LinearRegression,LassoCV, Ridge, LassoLarsCV,ElasticNetCV
from sklearn.model_selection import GridSearchCV, cross_val_score, learning_curve
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, Normalizer, RobustScaler

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
df['date'] = pd.to_datetime({'year':df.date.str[:4], 'month':df.date.str[4:6], 'day':df.date.str[6:8]})
# cleaning up 'date' column

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
df.shape # 19 house features plus the price and the id columns, along with 21613 observations.
# Out:
# (21613, 21)

# %%
df['price'].describe() # describes price summary statistics, mean price of 540,008.81
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
sns.distplot(df['price'] , fit=norm)

# %% [markdown]
# Distibution of house price is right skewed because mean price (540k) is greater than the median (450k).

# %%
# Top 10 Heatmap
n = 20 #number of variables for heatmap
corrmat = df.corr()
cols = corrmat.nlargest(n, 'price')['price'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Based on correlation matrix, following variables (bathrooms, sqft_living, grade, sqft_above, sqft_living15) are highly correlated to price.

# %%
corrmat.loc[((corrmat.price > 0.4) | (corrmat.price < -0.4)), 'price':'price']
# Out:
#                   price
# price          1.000000
# bathrooms      0.525138
# sqft_living    0.702035
# grade          0.667434
# sqft_above     0.605567
# sqft_living15  0.585379

# %%
df.plot.scatter(x='sqft_living',y='price',c='green')#see postive correlation between price and sqft living area

# %%
sns.boxplot(x="floors", y="price", data=df)#not much correlation between floors and price

# %%
sns.boxplot(x="waterfront", y="price", data=df)#seems to be a higher price for water front property.

# %%
df.plot.scatter(x='lat',y='price',c='green') #latitude also does not seem to have strong correlation.

# %%
sns.boxplot(x="bedrooms", y="price", data=df)#price seems to go up for number of bedrooms. house with 33 bedrooms is interesting.

# %%
df.plot.scatter(x='sqft_basement',y='price',c='green') #Hire sqft_basement, higher the price but not strong correlation

# %%
sns.boxplot(x="bathrooms", y="price", data=df)  #more bathrooms, higher the price

# %%
sns.boxplot(x="view", y="price", data=df) #better the view, the higher the price

# %%
df.plot.scatter(x='sqft_living',y='price',c='green') #higher the squarefoootage of living area, higher the price

# %%
sns.boxplot(x="grade", y="price", data=df) #better the grade, the better the price, really high correlation.
